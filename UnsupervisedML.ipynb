# %% [markdown]
# # DATA SCIENCE PROJECT - Unsupervised Machine Learning
# ## Antoine GOULARD - Reda FALAKI - Capucine FOUCHER

# %% [markdown]
# ### Importing Libraries

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage

# %% [markdown]
# ### Step 1 - Load the Data

# %%
# Importing the dataset
data = pd.read_csv("data/cleaned_data.csv")

# Extract the "valeur foncière" column
target_column = "Valeur fonciere"
y = data[target_column]

# %% [markdown]
# ### Step 2 - Instantiate, fit and analysis of the model chosen

# %%
# Iterate over each column (except the target column)
for column in data.columns:
    if column != target_column:
        # Extract the column
        X = data[column]
        
        # Reshape the data for KMeans input
        X = X.values.reshape(-1, 1)
        
        # Instantiate the KMeans model with the desired number of clusters
        kmeans = KMeans(n_clusters=3, random_state=42)
        
        # Fit the model to your data
        kmeans.fit(X)
        
        # Get the cluster labels for each data point
        cluster_labels = kmeans.labels_
        # Get the coordinates of the cluster centers
        cluster_centers = kmeans.cluster_centers_
        
        # Visualize the clusters
        plt.scatter(X, y, c=cluster_labels)
        plt.xlabel(column)
        plt.ylabel(target_column)
        plt.title(f"Clustering: {column} vs {target_column}")
        plt.scatter(cluster_centers, cluster_centers, c="red", s=200, alpha=0.5)
        plt.show()
        
        # Print cluster centers and labels
        print("Cluster Centers:")
        print(cluster_centers)
        print("Cluster Labels:")
        print(cluster_labels)
# Out:
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster Centers:
# [[8.46545056e-16]
#  [1.00000000e+00]
#  [2.40875912e+00]]
# Cluster Labels:
# [1 1 0 ... 0 0 0]
# Cluster Centers:
# [[ 8.10739726]
#  [ 0.72200868]
#  [54.35454545]]
# Cluster Labels:
# [1 1 1 ... 1 1 1]
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster Centers:
# [[21482.67145568]
#  [82117.42773925]
#  [51345.91832964]]
# Cluster Labels:
# [0 1 2 ... 1 0 2]
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster Centers:
# [[-4.38538095e-15]
#  [ 1.00000000e+00]
#  [ 2.27514231e+00]]
# Cluster Labels:
# [1 1 0 ... 0 0 0]
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster Centers:
# [[   32.10530007]
#  [28900.        ]
#  [ 4639.61111111]]
# Cluster Labels:
# [0 0 0 ... 0 0 0]
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster Centers:
# [[3.0815828 ]
#  [0.04626928]
#  [5.70899471]]
# Cluster Labels:
# [1 1 1 ... 1 1 1]
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster Centers:
# [[ 0.77322302]
#  [ 6.85874439]
#  [16.58577406]]
# Cluster Labels:
# [0 0 1 ... 1 0 1]
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster Centers:
# [[ 0.09269977]
#  [79.75      ]
#  [23.23529412]]
# Cluster Labels:
# [0 0 0 ... 0 0 0]
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster Centers:
# [[  814.50628607]
#  [83536.32142857]
#  [21208.42537313]]
# Cluster Labels:
# [0 0 0 ... 0 2 0]
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster Centers:
# [[7.23590944e+01]
#  [9.53200000e+03]
#  [7.16899095e-01]]
# Cluster Labels:
# [2 2 2 ... 2 2 2]
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster Centers:
# [[   56.76127214]
#  [22458.88888889]
#  [ 5338.47272727]]
# Cluster Labels:
# [0 0 0 ... 0 0 0]
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /var/folders/f6/zj0sqhqs6plbyp5r0kckp5340000gn/T/ipykernel_20815/848225053.py:14: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Cluster Centers:
# [[-1.94289029e-16]
#  [ 1.00000000e+00]
#  [ 0.00000000e+00]]
# Cluster Labels:
# [0 0 0 ... 0 0 0]
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /var/folders/f6/zj0sqhqs6plbyp5r0kckp5340000gn/T/ipykernel_20815/848225053.py:14: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Cluster Centers:
# [[-5.21804822e-15]
#  [ 1.00000000e+00]
#  [ 0.00000000e+00]]
# Cluster Labels:
# [0 0 0 ... 0 0 0]
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /var/folders/f6/zj0sqhqs6plbyp5r0kckp5340000gn/T/ipykernel_20815/848225053.py:14: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Cluster Centers:
# [[2.77555756e-17]
#  [1.00000000e+00]
#  [0.00000000e+00]]
# Cluster Labels:
# [0 0 0 ... 0 0 0]
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /var/folders/f6/zj0sqhqs6plbyp5r0kckp5340000gn/T/ipykernel_20815/848225053.py:14: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Cluster Centers:
# [[1.00000000e+00]
#  [1.44328993e-15]
#  [0.00000000e+00]]
# Cluster Labels:
# [1 1 1 ... 1 1 1]
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /var/folders/f6/zj0sqhqs6plbyp5r0kckp5340000gn/T/ipykernel_20815/848225053.py:14: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Cluster Centers:
# [[-6.66133815e-16]
#  [ 1.00000000e+00]
#  [ 1.00000000e+00]]
# Cluster Labels:
# [1 1 1 ... 1 1 1]

# %%
# Extract the "valeur foncière" column
target_column = "Valeur fonciere"
y = data[target_column]

# Get the number of columns (excluding the target column)
num_columns = len(data.columns) - 1

# Calculate the grid size for subplots
grid_size = int(np.ceil(np.sqrt(num_columns)))

# Create a figure and a grid of subplots
fig, axes = plt.subplots(grid_size, grid_size, figsize=(12, 12))
axes = axes.flatten()

# Iterate over each column (except the target column)
for i, column in enumerate(data.columns):
    if column != target_column:
        # Extract the column
        X = data[column]

        # Reshape the data for KMeans input
        X = X.values.reshape(-1, 1)

        # Instantiate the KMeans model with the desired number of clusters
        kmeans = KMeans(n_clusters=3, random_state=42)

        # Fit the model to your data
        kmeans.fit(X)

        # Get the cluster labels for each data point
        cluster_labels = kmeans.labels_
        # Get the coordinates of the cluster centers
        cluster_centers = kmeans.cluster_centers_

        # Visualize the clusters in the corresponding subplot
        ax = axes[i]
        ax.scatter(X, y, c=cluster_labels)
        ax.set_xlabel(column)
        ax.set_ylabel(target_column)
        ax.set_title(f"Clustering: {column} vs {target_column}")
        ax.scatter(cluster_centers, cluster_centers, c="red", s=200, alpha=0.5)

        # Print cluster centers and labels
        print("Cluster Centers:")
        print(cluster_centers)
        print("Cluster Labels:")
        print(cluster_labels)

# Remove any empty subplots
if num_columns < len(axes):
    for j in range(num_columns, len(axes)):
        fig.delaxes(axes[j])

# Adjust the spacing between subplots
fig.tight_layout()

# Show the plot
plt.show()
# Out:
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster Centers:
# [[8.46545056e-16]
#  [1.00000000e+00]
#  [2.40875912e+00]]
# Cluster Labels:
# [1 1 0 ... 0 0 0]
# Cluster Centers:
# [[ 8.10739726]
#  [ 0.72200868]
#  [54.35454545]]
# Cluster Labels:
# [1 1 1 ... 1 1 1]
# Cluster Centers:
# [[21482.67145568]
#  [82117.42773925]
#  [51345.91832964]]
# Cluster Labels:
# [0 1 2 ... 1 0 2]
# Cluster Centers:
# [[-4.38538095e-15]
#  [ 1.00000000e+00]
#  [ 2.27514231e+00]]
# Cluster Labels:
# [1 1 0 ... 0 0 0]
# Cluster Centers:
# [[   32.10530007]
#  [28900.        ]
#  [ 4639.61111111]]
# Cluster Labels:
# [0 0 0 ... 0 0 0]
# Cluster Centers:
# [[3.0815828 ]
#  [0.04626928]
#  [5.70899471]]
# Cluster Labels:
# [1 1 1 ... 1 1 1]
# Cluster Centers:
# [[ 0.77322302]
#  [ 6.85874439]
#  [16.58577406]]
# Cluster Labels:
# [0 0 1 ... 1 0 1]
# Cluster Centers:
# [[ 0.09269977]
#  [79.75      ]
#  [23.23529412]]
# Cluster Labels:
# [0 0 0 ... 0 0 0]
# Cluster Centers:
# [[  814.50628607]
#  [83536.32142857]
#  [21208.42537313]]
# Cluster Labels:
# [0 0 0 ... 0 2 0]
# Cluster Centers:
# [[7.23590944e+01]
#  [9.53200000e+03]
#  [7.16899095e-01]]
# Cluster Labels:
# [2 2 2 ... 2 2 2]
# Cluster Centers:
# [[   56.76127214]
#  [22458.88888889]
#  [ 5338.47272727]]
# Cluster Labels:
# [0 0 0 ... 0 0 0]
# Cluster Centers:
# [[-2.22044605e-16]
#  [ 1.00000000e+00]
#  [ 0.00000000e+00]]
# Cluster Labels:
# [0 0 0 ... 0 0 0]
# Cluster Centers:
# [[-5.21804822e-15]
#  [ 1.00000000e+00]
#  [ 0.00000000e+00]]
# Cluster Labels:
# [0 0 0 ... 0 0 0]
# Cluster Centers:
# [[2.77555756e-17]
#  [1.00000000e+00]
#  [0.00000000e+00]]
# Cluster Labels:
# [0 0 0 ... 0 0 0]
# Cluster Centers:
# [[1.00000000e+00]
#  [1.41553436e-15]
#  [0.00000000e+00]]
# Cluster Labels:
# [1 1 1 ... 1 1 1]
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /var/folders/f6/zj0sqhqs6plbyp5r0kckp5340000gn/T/ipykernel_20815/2988996445.py:28: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /var/folders/f6/zj0sqhqs6plbyp5r0kckp5340000gn/T/ipykernel_20815/2988996445.py:28: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /var/folders/f6/zj0sqhqs6plbyp5r0kckp5340000gn/T/ipykernel_20815/2988996445.py:28: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /var/folders/f6/zj0sqhqs6plbyp5r0kckp5340000gn/T/ipykernel_20815/2988996445.py:28: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# /Users/capucinefoucher/Desktop/HousePricing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /var/folders/f6/zj0sqhqs6plbyp5r0kckp5340000gn/T/ipykernel_20815/2988996445.py:28: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[65], line 36
#      33 cluster_centers = kmeans.cluster_centers_
#      35 # Visualize the clusters in the corresponding subplot
# ---> 36 ax = axes[i]
#      37 ax.scatter(X, y, c=cluster_labels)
#      38 ax.set_xlabel(column)
#
# IndexError: index 16 is out of bounds for axis 0 with size 16
